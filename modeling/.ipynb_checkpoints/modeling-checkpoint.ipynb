# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import os
import seaborn as sns

# %%
# Read CSVs
PatientConsumption = pd.read_csv('PatientConsumption 2018-2019.csv').drop_duplicates()
PurchasedOrders    = pd.read_csv('PurchasedOrders 2018-2019.csv').drop_duplicates()
IncompleteOrders   = pd.read_csv('IncompleteOrders 2018-2019.csv').drop_duplicates()
PatentDrugs        = pd.read_csv('Diccionario_v3.csv').drop_duplicates()

# Retrieve date columns and apply to_datetime, set amount columns as numeric
date_columns   = [column for column in PatientConsumption.columns if 'Date' in column]
amount_columns = [column for column in PatientConsumption.keys() if 'Amount' in column]
PatientConsumption[date_columns]   = PatientConsumption[date_columns].apply(pd.to_datetime)
PatientConsumption[amount_columns] = PatientConsumption[amount_columns].astype(int)

date_columns   = [column for column in PurchasedOrders.columns if 'Date' in column]
amount_columns = [column for column in PurchasedOrders.keys() if 'Amount' in column]
PurchasedOrders[date_columns]   = PurchasedOrders[date_columns].apply(pd.to_datetime)
PurchasedOrders[amount_columns] = PurchasedOrders[amount_columns].astype(int)

date_columns   = [column for column in IncompleteOrders.columns if 'Date' in column]
amount_columns = [column for column in IncompleteOrders.keys() if 'Amount' in column]
IncompleteOrders[date_columns]   = IncompleteOrders[date_columns].apply(pd.to_datetime)
IncompleteOrders[amount_columns] = IncompleteOrders[amount_columns].astype(int)

# %% [markdown]
# ___
# ## Time series

# %%
TopMeds=['COMBIVENT 0.5/2.5MG AMPOLLETA 2.5ML (IPRATROPIO/ SALBUTAMOL)',
        'FIRAC PLUS 100MG AMP (CLONIXINATO LISINA/PARGEVER)',
        'FLIXOTIDE 2MG AMP 2ML (FLUTICASONA)',
        'SOMAZINA 1G AMP 4ML (CITICOLINA)',
        'INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)',
        'MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL',
        'VANCOCIN CP 1G AMP (VANCOMICINA)',
        'COMBIVENT RESPIMAT 1.68/8.77MG C/DOSIF.(IPRATRO./ SALBUTAMOL',
        'LIPITOR 80MG C/30 TAB(ATORVASTATINA)']

# %%
# Consumed
MedConsumption = pd.merge(PatientConsumption, PatentDrugs[['MedCode','MedFamily','Compound']], on='MedCode', how='left')
# Requested, Purchased
MedOrders = pd.merge(PurchasedOrders, PatentDrugs[['MedCode','MedFamily','Compound']], on='MedCode', how='left')
MedOrders['YearMonth'] = pd.to_datetime(MedOrders['RequestDate'].dt.year*100+MedOrders['RequestDate'].dt.month, format='%Y%m')
# Incomplete
MedIncompleteOrders = pd.merge(IncompleteOrders[IncompleteOrders['RequestNumber']!=0], PatentDrugs[['MedCode','MedFamily','Compound']], on='MedCode', how='left')
MedIncompleteOrders['YearMonth'] = pd.to_datetime(MedIncompleteOrders['RequestDate'].dt.year*100+MedIncompleteOrders['RequestDate'].dt.month, format='%Y%m')

# %%
AmountRequested = MedOrders[['YearMonth','RequestNumber','MedCode','AmountRequested']].drop_duplicates()
AmountPurchased = MedOrders.groupby(['YearMonth','RequestNumber','MedCode']).sum()['AmountPurchased'].reset_index()
AmountReceived = MedIncompleteOrders.groupby(['YearMonth','RequestNumber','MedCode']).sum()['AmountReceived'].reset_index()

# Merge columns
df = pd.merge(AmountRequested, AmountPurchased, on=['YearMonth','RequestNumber','MedCode'], how='left')
df = pd.merge(df, AmountReceived, on=['YearMonth','RequestNumber','MedCode'], how='left')
# if AmountReceived.isna() : order is complete
df['AmountReceived'] = df.apply(lambda x: x['AmountPurchased'] if pd.isna(x['AmountReceived']) else x['AmountReceived'], axis=1)
# compute shortage amount
df['AmountMissing'] = df['AmountRequested'] - df['AmountReceived']

df[(df['AmountPurchased']!=df['AmountReceived']) & (df['AmountRequested']!=df['AmountPurchased'])].head()
# Out:
#       YearMonth  RequestNumber  MedCode  AmountRequested  AmountPurchased  \
# 438  2018-01-01          52936  3300586                1                2
# 677  2018-01-01          53062  3300627               10               19
# 717  2018-01-01          53076  3300952               15               30
# 1975 2018-03-01          53801  3305045               20              270
# 2069 2018-03-01          53877  3300072               18               20
#
#       AmountReceived  AmountMissing
# 438              0.0            1.0
# 677              1.0            9.0
# 717              0.0           15.0
# 1975             0.0           20.0
# 2069             0.0           18.0

# %%
AmountOrder = df.groupby(['YearMonth','MedCode']).sum()[['AmountRequested','AmountPurchased','AmountReceived','AmountMissing']].reset_index()
AmountOrder.head(5)
# Out:
#    YearMonth  MedCode  AmountRequested  AmountPurchased  AmountReceived  \
# 0 2018-01-01  1000268               15               18            18.0
# 1 2018-01-01  2900193                2                2             2.0
# 2 2018-01-01  2900517                7                6             5.0
# 3 2018-01-01  3300018                2                2             0.0
# 4 2018-01-01  3300029                1                1             1.0
#
#    AmountMissing
# 0           -3.0
# 1            0.0
# 2            2.0
# 3            2.0
# 4            0.0

# %%
AmountConsumed = MedConsumption.groupby(['ConsumptionDate','MedCode']).sum()['AmountConsumed'].reset_index()
AmountConsumed['YearMonth'] = pd.to_datetime(AmountConsumed['ConsumptionDate'].dt.year*100+AmountConsumed['ConsumptionDate'].dt.month, format='%Y%m')
AmountConsumed = AmountConsumed.loc[:, ['YearMonth','MedCode','AmountConsumed']]
AmountConsumed.head()
# Out:
#    YearMonth    MedCode  AmountConsumed
# 0 2018-01-01  1000268.0              22
# 1 2018-01-01  2900193.0               2
# 2 2018-01-01  2900517.0               3
# 3 2018-01-01  3300018.0               1
# 4 2018-01-01  3300029.0               1

# %%
MonthlyMeds = pd.merge(AmountOrder, AmountConsumed, on=['YearMonth','MedCode'], how='outer')
# fill AmountConsumed.isna() with zeros
#MonthlyMeds['AmountConsumed'] = MonthlyMeds['AmountConsumed'].fillna(0)
MonthlyMeds = MonthlyMeds.fillna(0)
MonthlyMeds.head()
# Out:
#    YearMonth  MedCode  AmountRequested  AmountPurchased  AmountReceived  \
# 0 2018-01-01  1000268             15.0             18.0            18.0
# 1 2018-01-01  2900193              2.0              2.0             2.0
# 2 2018-01-01  2900517              7.0              6.0             5.0
# 3 2018-01-01  3300018              2.0              2.0             0.0
# 4 2018-01-01  3300029              1.0              1.0             1.0
#
#    AmountMissing  AmountConsumed
# 0           -3.0            22.0
# 1            0.0             2.0
# 2            2.0             3.0
# 3            2.0             1.0
# 4            0.0             1.0

# %%
MonthlyMeds = pd.merge(MonthlyMeds, PatentDrugs[['MedCode','MedDescription']], on='MedCode', how='left')
MonthlyMeds.head(5)
# Out:
#    YearMonth  MedCode  AmountRequested  AmountPurchased  AmountReceived  \
# 0 2018-01-01  1000268             15.0             18.0            18.0
# 1 2018-01-01  2900193              2.0              2.0             2.0
# 2 2018-01-01  2900517              7.0              6.0             5.0
# 3 2018-01-01  3300018              2.0              2.0             0.0
# 4 2018-01-01  3300029              1.0              1.0             1.0
#
#    AmountMissing  AmountConsumed  \
# 0           -3.0            22.0
# 1            0.0             2.0
# 2            2.0             3.0
# 3            2.0             1.0
# 4            0.0             1.0
#
#                                       MedDescription
# 0              HALOPERIL 5MG/ML AMP IM (HALOPERIDOL)
# 1  REFRESH TEARS GTS 15ML (CARBOXIMETILCELULOSA S...
# 2                    ALBUMINA DE HUEVO 400GR OVOPROT
# 3                 LYRICA 150MG C/14 TAB(PREGABALINA)
# 4  ADIMOD SOLUCION 800MG/7ML CAJA C/10 FCO (PIDOT...

# %%
# Plot top Meds
fig, axes = plt.subplots(5, 2, figsize=(20,30))
fig.subplots_adjust(hspace=0.5)
for ax, MedCode in zip(axes.flatten(), TopMeds):
    sns.lineplot(data=MonthlyMeds[MonthlyMeds["MedDescription"]==MedCode], x='YearMonth', y='AmountRequested', ax=ax)
    sns.lineplot(data=MonthlyMeds[MonthlyMeds["MedDescription"]==MedCode], x='YearMonth', y='AmountPurchased', ax=ax)
    #sns.lineplot(data=MonthlyMeds[MonthlyMeds["MedDescription"]==MedCode], x='YearMonth', y='AmountReceived', ax=ax)
    sns.lineplot(data=MonthlyMeds[MonthlyMeds["MedDescription"]==MedCode], x='YearMonth', y='AmountMissing', ax=ax)
    sns.lineplot(data=MonthlyMeds[MonthlyMeds["MedDescription"]==MedCode], x='YearMonth', y='AmountConsumed', ax=ax)
    #ax.legend(["AmountRequested","AmountPurchased",'AmountReceived','AmountMissing','AmountConsumed'])
    ax.legend(["AmountRequested","AmountPurchased",'AmountMissing','AmountConsumed'])
    ax.tick_params('x', labelrotation=30)
    ax.set(title=MedCode)

# %%
plt.figure(figsize=(6,4))
sns.heatmap(data=MonthlyMeds.corr(), annot=True);

# %% [markdown]
# ___

# %%
top_meds = MonthlyMeds[MonthlyMeds["MedDescription"].isin(TopMeds)].sort_values(['MedCode','YearMonth']).reset_index(drop=True)
top_meds
# Out:
#      YearMonth  MedCode  AmountRequested  AmountPurchased  AmountReceived  \
# 0   2018-01-01  3300115             75.0             55.0            55.0
# 1   2018-02-01  3300115             70.0             70.0            70.0
# 2   2018-03-01  3300115             97.0             97.0            97.0
# 3   2018-04-01  3300115             73.0             73.0            57.0
# 4   2018-05-01  3300115             35.0             35.0            35.0
# ..         ...      ...              ...              ...             ...
# 211 2019-08-01  3500322            106.0            106.0           106.0
# 212 2019-09-01  3500322            126.0            126.0           126.0
# 213 2019-10-01  3500322            125.0            127.0           127.0
# 214 2019-11-01  3500322             92.0             92.0            92.0
# 215 2019-12-01  3500322             70.0             70.0            70.0
#
#      AmountMissing  AmountConsumed  \
# 0             20.0            58.0
# 1              0.0            71.0
# 2              0.0            78.0
# 3             16.0            69.0
# 4              0.0            47.0
# ..             ...             ...
# 211            0.0           100.0
# 212            0.0           116.0
# 213           -2.0           146.0
# 214            0.0            89.0
# 215            0.0            74.0
#
#                                     MedDescription
# 0       INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)
# 1       INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)
# 2       INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)
# 3       INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)
# 4       INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)
# ..                                             ...
# 211  MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL
# 212  MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL
# 213  MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL
# 214  MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL
# 215  MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL
#
# [216 rows x 8 columns]

# %%
TopMedCodes = PatentDrugs[PatentDrugs['MedDescription'].isin(TopMeds)]['MedCode']
PatentDrugs[PatentDrugs['MedDescription'].isin(TopMeds)]
# Out:
#       MedCode                                     MedDescription  \
# 14    3300115         INDAFLEX 2.5% CREMA 40G TUBO(INDOMETACINA)
# 37    3300142               LIPITOR 80MG C/30 TAB(ATORVASTATINA)
# 202   3300663                   VANCOCIN CP 1G AMP (VANCOMICINA)
# 517   3301778                FLIXOTIDE 2MG AMP 2ML (FLUTICASONA)
# 548   3301771                   SOMAZINA 1G AMP 4ML (CITICOLINA)
# 631   3302307  FIRAC PLUS 100MG AMP (CLONIXINATO LISINA/PARGE...
# 795   3302934  COMBIVENT RESPIMAT 1.68/8.77MG C/DOSIF.(IPRATR...
# 1495  3500322      MYDOCALM A C/30 CAPS TOLPERISONA /PARACETAMOL
# 1585  3302669  COMBIVENT 0.5/2.5MG AMPOLLETA 2.5ML (IPRATROPI...
#
#                          Compound                           MedFamily  \
# 14                   INDOMETACINA          Sistema musculoesquelético
# 37                  ATORVASTATINA              Sistema cardiovascular
# 202                   VANCOMICINA  Antiinfecciosos para uso sistémico
# 517                   FLUTICASONA                Sistema respiratorio
# 548                    CITICOLINA                    Sistema nervioso
# 631   CLONIXINATO LISINA/PARGEVER    Tracto alimentario y metabolismo
# 795        IPRATROPIO/ SALBUTAMOL                Sistema respiratorio
# 1495                     MYDOCALM          Sistema musculoesquelético
# 1585       IPRATROPIO/ SALBUTAMOL                Sistema respiratorio
#
#       MedPriceMXN  MinStock  MaxStock
# 14          719.0        21        59
# 37          801.0         5        13
# 202        1059.0        26        74
# 517         720.5       118       306
# 548         209.5        55       125
# 631         152.5        29        84
# 795         669.5         4         8
# 1495        613.0        52       114
# 1585        528.5       591      1608

# %% [markdown]
# ___
# # Timeseries prediction

# %%
import tensorflow as tf
import matplotlib as mpl

# %%
tf.random.set_seed(42)

# %%
'''
MedFamily = PatentDrugs[PatentDrugs['MedFamily']=='Sistema respiratorio']['MedCode']
MonthlyFamily = MonthlyMeds[MonthlyMeds['MedCode'].isin(MedFamily)]
NumMonths     = MonthlyFamily.groupby(['MedCode','YearMonth']).count().reset_index().groupby('MedCode').count().sort_values('YearMonth', ascending=False)
NumMonths24   = NumMonths[NumMonths['YearMonth']==24].index.values
NumMonths24
'''

NumMonths     = MonthlyMeds.groupby(['MedCode','YearMonth']).count().reset_index().groupby('MedCode').count().sort_values('YearMonth', ascending=False)
NumMonths24   = NumMonths[NumMonths['YearMonth']==24].index.values
NumMonths24.shape
# Out:
# (87,)

# %%
# Concat TipMeds at the end for prediction
MedFamily24 = MonthlyMeds[(MonthlyMeds['MedCode'].isin(NumMonths24)) & (~MonthlyMeds['MedCode'].isin(TopMedCodes))]
MedFamily24 = pd.concat([MedFamily24, MonthlyMeds[MonthlyMeds['MedCode'].isin(TopMedCodes)]], ignore_index=True)

plt.figure(figsize=(10,7))
sns.lineplot(data=MedFamily24, x='YearMonth', y='AmountConsumed', hue='MedDescription', legend=False)
plt.xticks(rotation=30);

# %% [markdown]
# ## Univariate LSTM model

# %%
uni_data = MedFamily24.set_index('MedCode')['AmountConsumed']

uni_data_norm = []
for i, MedCode in enumerate(uni_data.index.unique()):
    chunk = uni_data[uni_data.index==MedCode].values
    chunk = (chunk - chunk.mean()) / chunk.std()
    chunk.reshape(len(chunk),1)
    uni_data_norm.append(chunk)

uni_data_norm = np.array(uni_data_norm)
print(uni_data_norm.shape)
# Out:
# (87, 24)

# %%
plt.figure(figsize=(10,7))
for i in range(uni_data_norm.shape[0]):
    sns.lineplot(data=uni_data_norm[i]).set(title='Normalized features');

# %%
# train & validation splits

#TRAIN_SPLIT = 80
TRAIN_SPLIT = uni_data_norm.shape[0]-len(TopMeds)

length = uni_data_norm.shape[1]
x_train_uni = []
y_train_uni = []
x_val_uni = []
y_val_uni = []

for Med in range(uni_data_norm.shape[0]):
    if Med < TRAIN_SPLIT:
        x_train_uni.append(uni_data_norm[Med][:length-1].reshape(length-1,1))
        y_train_uni.append(uni_data_norm[Med][length-1])
    else:
        x_val_uni.append(uni_data_norm[Med][:length-1].reshape(length-1,1))
        y_val_uni.append(uni_data_norm[Med][length-1])

x_train_uni = np.array(x_train_uni)
y_train_uni = np.array(y_train_uni)
x_val_uni = np.array(x_val_uni)
y_val_uni = np.array(y_val_uni)

print(x_train_uni.shape, y_train_uni.shape)
print(x_val_uni.shape, y_val_uni.shape)
# Out:
# (78, 23, 1) (78,)
# (9, 23, 1) (9,)

# %%
BATCH_SIZE = 1 # Stochastic Gradient Descent
BUFFER_SIZE = 1

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

# %%
#def root_mean_squared_error(y_true, y_pred):
#    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))

uni_model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
        tf.keras.layers.Dense(1)
    ])

uni_model.compile(optimizer='adam', loss='mae')

# %%
EPOCHS = 10
EVALUATION_INTERVAL = 200

uni_model.fit(train_univariate, epochs=EPOCHS,
    steps_per_epoch=EVALUATION_INTERVAL,
    validation_data=val_univariate, validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/10
# 200/200 [==============================] - 13s 65ms/step - loss: 0.7782 - val_loss: 0.8061
# Epoch 2/10
# 200/200 [==============================] - 6s 31ms/step - loss: 0.6574 - val_loss: 0.7136
# Epoch 3/10
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6622 - val_loss: 0.6947
# Epoch 4/10
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6397 - val_loss: 0.6891
# Epoch 5/10
# 200/200 [==============================] - 7s 33ms/step - loss: 0.6222 - val_loss: 0.6847
# Epoch 6/10
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6075 - val_loss: 0.6569
# Epoch 7/10
# 200/200 [==============================] - 5s 26ms/step - loss: 0.5748 - val_loss: 0.6400
# Epoch 8/10
# 200/200 [==============================] - 7s 35ms/step - loss: 0.5777 - val_loss: 0.7665
# Epoch 9/10
# 200/200 [==============================] - 7s 37ms/step - loss: 0.5602 - val_loss: 0.5813
# Epoch 10/10
# 200/200 [==============================] - 5s 24ms/step - loss: 0.5750 - val_loss: 0.6145

# %%
def create_time_steps(length):
    return list(range(-length, 0))

def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10,
                             label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
val_uni_size = x_val_uni.shape[0]

plt.figure(figsize=(13,15))
for i, (x, y) in enumerate(val_univariate.take(val_uni_size)):
    plt.subplot(np.ceil(val_uni_size/2), 2, i+1)
    plot = show_plot([x[0].numpy(), y[0].numpy(), uni_model.predict(x)[0]], 0, 'Simple LSTM model')
plot.tight_layout(pad=0.7)
plot.show()

# %%
losses_uni = np.array([uni_model.evaluate(x, y) for x, y in val_univariate.take(val_uni_size)])
sns.boxplot(data=losses_uni).set(title='Validation split loss', ylabel='MAE')
plt.show();
print('Average MAE: %.4f' % np.mean(losses_uni))

# %% [markdown]
# ## Multivariate LSTM model

# %%
one_hot_MedFamily = pd.get_dummies(PatentDrugs[['MedCode','MedFamily']], prefix='', prefix_sep='')
multi_data = pd.merge(MedFamily24[['MedCode','AmountConsumed']], one_hot_MedFamily, on='MedCode', how='left').set_index('MedCode')

multi_data_norm = []
for i, MedCode in enumerate(multi_data.index.unique()):
    chunk = np.array(multi_data[multi_data.index==MedCode].values)
    chunk[:,0] = (chunk[:,0] - chunk[:,0].mean()) / chunk[:,0].std() # Binary attributes not reshaped
    chunk.reshape(chunk.shape[0], chunk.shape[1], 1)
    multi_data_norm.append(chunk)

multi_data_norm = np.array(multi_data_norm)
print(multi_data_norm.shape)
# Out:
# (87, 24, 18)

# %%
plt.figure(figsize=(10,7))
for i in range(multi_data_norm.shape[0]):
    sns.lineplot(data=multi_data_norm[i][:,0]).set(title='Normalized non-binary features');

# %%
# train & validation splits

#TRAIN_SPLIT = 80
TRAIN_SPLIT = uni_data_norm.shape[0]-len(TopMeds)

length = multi_data_norm.shape[1]
num_features = multi_data_norm.shape[2]
x_train_multi = []
y_train_multi = []
x_val_multi = []
y_val_multi = []

for Med in range(multi_data_norm.shape[0]):
    if Med < TRAIN_SPLIT:
        x_train_multi.append(multi_data_norm[Med][:length-1].reshape(length-1,num_features))
        y_train_multi.append(multi_data_norm[Med][length-1][0])
    else:
        x_val_multi.append(multi_data_norm[Med][:length-1].reshape(length-1,num_features))
        y_val_multi.append(multi_data_norm[Med][length-1][0])

x_train_multi = np.array(x_train_multi)
y_train_multi = np.array(y_train_multi)
x_val_multi = np.array(x_val_multi)
y_val_multi = np.array(y_val_multi)

print(x_train_multi.shape, y_train_multi.shape)
print(x_val_multi.shape, y_val_multi.shape)
# Out:
# (80, 23, 18) (80,)
# (7, 23, 18) (7,)

# %%
BATCH_SIZE = 1 # Stochastic Gradient Descent
BUFFER_SIZE = 1

train_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_multi = train_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_multi = val_multi.batch(BATCH_SIZE).repeat()

# %%
#def root_mean_squared_error(y_true, y_pred):
#    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))

multi_model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(32, input_shape=x_train_multi.shape[-2:]),
        tf.keras.layers.Dense(1)
    ])

multi_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %%
multi_model_hist = multi_model.fit( train_multi,
                                    epochs=EPOCHS,
                                    steps_per_epoch=EVALUATION_INTERVAL,
                                    validation_data=val_multi,
                                    validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/10
# 200/200 [==============================] - 16s 80ms/step - loss: 0.7654 - val_loss: 0.5696
# Epoch 2/10
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6982 - val_loss: 0.5334
# Epoch 3/10
# 200/200 [==============================] - 9s 45ms/step - loss: 0.6806 - val_loss: 0.4765
# Epoch 4/10
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6543 - val_loss: 0.5259
# Epoch 5/10
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6464 - val_loss: 0.5617
# Epoch 6/10
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6228 - val_loss: 0.4900
# Epoch 7/10
# 200/200 [==============================] - 9s 44ms/step - loss: 0.5926 - val_loss: 0.5047
# Epoch 8/10
# 200/200 [==============================] - 9s 44ms/step - loss: 0.5524 - val_loss: 0.4746
# Epoch 9/10
# 200/200 [==============================] - 9s 45ms/step - loss: 0.5218 - val_loss: 0.4645
# Epoch 10/10
# 200/200 [==============================] - 10s 52ms/step - loss: 0.5116 - val_loss: 0.4245

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

plot_train_history(multi_model_hist, 'Single Step Training and validation loss')

# %%
val_multi_size = x_val_multi.shape[0]

plt.figure(figsize=(13,15))
for i, (x, y) in enumerate(val_multi.take(val_multi_size)):
    plt.subplot(np.ceil(val_multi_size/2), 2, i+1)
    plot = show_plot([x[0][:,0].numpy(), y[0].numpy(), multi_model.predict(x)[0]], 0, 'Multivariate LSTM model')
plot.tight_layout(pad=0.7)
plot.show()

# %%
losses_multi = np.array([multi_model.evaluate(x, y) for x, y in val_multi.take(val_multi_size)])
sns.boxplot(data=losses_multi).set(title='Validation split loss', ylabel='MAE')
plt.show();
print('Average MAE: %.4f' % np.mean(losses_multi))
# Out:
# 1/1 [==============================] - 1s 1s/sample - loss: 1.3783
# 1/1 [==============================] - 0s 19ms/sample - loss: 0.0614
# 1/1 [==============================] - 0s 9ms/sample - loss: 0.1456
# 1/1 [==============================] - 0s 14ms/sample - loss: 0.3522
# 1/1 [==============================] - 0s 8ms/sample - loss: 0.2346
# 1/1 [==============================] - 0s 19ms/sample - loss: 0.0935
# 1/1 [==============================] - 0s 10ms/sample - loss: 0.5699
# Average MAE: 0.4051

# %% [markdown]
# ## Univariate multi-step LSTM model

# %%
uni_data = MedFamily24.set_index('MedCode')['AmountConsumed']

uni_data_norm = []
for i, MedCode in enumerate(uni_data.index.unique()):
    chunk = uni_data[uni_data.index==MedCode].values
    chunk = (chunk - chunk.mean()) / chunk.std()
    chunk.reshape(len(chunk),1)
    uni_data_norm.append(chunk)

uni_data_norm = np.array(uni_data_norm)
print(uni_data_norm.shape)
# Out:
# (87, 24)

# %%
# train & validation splits

# Validate using TopMeds
TRAIN_SPLIT = uni_data_norm.shape[0]-len(TopMeds)

future_target = 3
length = uni_data_norm.shape[1]-future_target+1
x_train_multistep = []
y_train_multistep = []
x_val_multistep = []
y_val_multistep = []

for Med in range(uni_data_norm.shape[0]):
    if Med < TRAIN_SPLIT:
        x_train_multistep.append(uni_data_norm[Med][:length-1].reshape(length-1,1))
        y_train_multistep.append(uni_data_norm[Med][length-1:])
    else:
        x_val_multistep.append(uni_data_norm[Med][:length-1].reshape(length-1,1))
        y_val_multistep.append(uni_data_norm[Med][length-1:])

x_train_multistep = np.array(x_train_multistep)
y_train_multistep = np.array(y_train_multistep)
x_val_multistep = np.array(x_val_multistep)
y_val_multistep = np.array(y_val_multistep)

print(x_train_multistep.shape, y_train_multistep.shape)
print(x_val_multistep.shape, y_val_multistep.shape)
# Out:
# (78, 21, 1) (78, 3)
# (9, 21, 1) (9, 3)

# %%
BATCH_SIZE = 1 # Stochastic Gradient Descent
BUFFER_SIZE = 1

train_multistep = tf.data.Dataset.from_tensor_slices((x_train_multistep, y_train_multistep))
train_multistep = train_multistep.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_multistep = tf.data.Dataset.from_tensor_slices((x_val_multistep, y_val_multistep))
val_multistep = val_multistep.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
    #plt.figure(figsize=(10, 5))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 0]), '.-', label='History')
    plt.plot(np.arange(num_out), np.array(true_future), 'b.-',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out), np.array(prediction), 'r.-',
             label='Predicted Future')
    plt.legend(loc='upper left')
    return plt

multi_step_plot(x_train_multistep[50], y_train_multistep[50], np.array([0]));

# %%
multistep_model =   tf.keras.models.Sequential([
                    tf.keras.layers.LSTM(32,
                          return_sequences=True,
                          input_shape=x_train_multistep.shape[-2:]),
                    tf.keras.layers.LSTM(16, activation='relu'),
                    tf.keras.layers.Dense(y_train_multistep.shape[-1])
    ])

multistep_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %%
multistep_history = multistep_model.fit(train_multistep,
                                        epochs=EPOCHS,
                                        steps_per_epoch=EVALUATION_INTERVAL,
                                        validation_data=val_multistep,
                                        validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/10
# 200/200 [==============================] - 26s 131ms/step - loss: 0.6944 - val_loss: 1.0204
# Epoch 2/10
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6305 - val_loss: 0.7449
# Epoch 3/10
# 200/200 [==============================] - 13s 65ms/step - loss: 0.5840 - val_loss: 0.6452
# Epoch 4/10
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5575 - val_loss: 0.6650
# Epoch 5/10
# 200/200 [==============================] - 13s 66ms/step - loss: 0.5348 - val_loss: 0.7202
# Epoch 6/10
# 200/200 [==============================] - 13s 65ms/step - loss: 0.5377 - val_loss: 0.7125
# Epoch 7/10
# 200/200 [==============================] - 13s 66ms/step - loss: 0.5161 - val_loss: 0.6325
# Epoch 8/10
# 200/200 [==============================] - 14s 68ms/step - loss: 0.5175 - val_loss: 0.6829
# Epoch 9/10
# 200/200 [==============================] - 13s 67ms/step - loss: 0.5173 - val_loss: 0.6422
# Epoch 10/10
# 200/200 [==============================] - 14s 68ms/step - loss: 0.5033 - val_loss: 0.7831

# %%
plot_train_history(multistep_history, 'Multi-Step Training and validation loss')

# %%
val_multistep_size = x_val_multistep.shape[0]

plt.figure(figsize=(13,15))
for i, (x, y) in enumerate(val_multistep.take(val_multistep_size)):
    plt.subplot(np.ceil(val_multistep_size/2), 2, i+1)
    multi_step_plot(x[0].numpy(), y[0].numpy(), multistep_model.predict(x)[0])
plot.tight_layout(pad=0.7)
plot.show()

# %%
losses_multistep = np.array([multistep_model.evaluate(x, y) for x, y in val_multistep.take(val_multistep_size)])
sns.boxplot(data=losses_multistep).set(title='Validation split loss', ylabel='MAE')
plt.show();
print('Average MAE: %.4f' % np.mean(losses_multistep))
# Out:
# 1/1 [==============================] - 2s 2s/sample - loss: 0.7275
# 1/1 [==============================] - 0s 16ms/sample - loss: 1.0317
# 1/1 [==============================] - 0s 12ms/sample - loss: 0.6539
# 1/1 [==============================] - 0s 17ms/sample - loss: 0.0976
# 1/1 [==============================] - 0s 11ms/sample - loss: 0.3499
# 1/1 [==============================] - 0s 12ms/sample - loss: 1.4212
# 1/1 [==============================] - 0s 13ms/sample - loss: 1.9000
# 1/1 [==============================] - 0s 12ms/sample - loss: 0.6656
# 1/1 [==============================] - 0s 21ms/sample - loss: 0.4111
# Average MAE: 0.8065
