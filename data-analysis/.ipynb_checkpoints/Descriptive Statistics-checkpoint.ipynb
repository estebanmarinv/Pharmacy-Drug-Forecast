# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import os
import seaborn as sns

# %%
#Read file 
consumption = pd.read_csv("Informe de consumo 2018-2019.csv")
orders= pd.read_csv("Requisiciones vs ordenes de compra 2018-2019.csv")
orders["FECHA"]=pd.to_datetime(orders["FECHA"], format="%YYY-")

# %%
desabastos=orders[orders["CANTIDAD PEDIDA"]==0]


plt.figure(figsize=(15, 5))

plt.hist(desabastos.FECHA, bins = 150, facecolor="m")

plt.title("Frequency of ratings for Videos over time")
plt.xlabel("Rating")
plt.ylabel("Frecuency of Rating")
plt.grid(True)
plt.show()

# %%
desabastos[desabastos["FECHA"]=="2019-10-02"]
# Out:
#        REQUISICIÓN      FECHA  ORDEN COMPRA FECHA PEDIDO FECHA ENTREGA  \
# 54165        64463 2019-10-02           NaN          NaN           NaN
# 54166        64463 2019-10-02           NaN          NaN           NaN
# 54207        64468 2019-10-02           NaN          NaN           NaN
# 54209        64472 2019-10-02           NaN          NaN           NaN
# 54210        64472 2019-10-02           NaN          NaN           NaN
# 54211        64472 2019-10-02           NaN          NaN           NaN
# 54212        64472 2019-10-02           NaN          NaN           NaN
# 54213        64472 2019-10-02           NaN          NaN           NaN
# 54214        64472 2019-10-02           NaN          NaN           NaN
# 54215        64472 2019-10-02           NaN          NaN           NaN
# 54216        64472 2019-10-02           NaN          NaN           NaN
# 54217        64472 2019-10-02           NaN          NaN           NaN
# ...
